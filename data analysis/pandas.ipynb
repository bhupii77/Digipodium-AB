# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### What do you need to learn
#
# - loading data
# - selection
#     - cols
#     - rows
# - manipulation
#     - add columns
#     - remove columns
#     - rename columns
#     - change data type
#     - delete data
#     - remove duplicates
#     - sort
#     - group
#     - pivot
#     - merge
# - visualization
#
#     - line plot
#     - bar plot
#     - histogram
#     - box plot
#     - scatter plot
#     - pie chart
#     - heatmap
#     - word cloud

# %%
penguins = sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# - analysis
#    - univariate analysis
#    - bi-variate analysis
#    - multi-variate analysis

# %% [markdown]
# - loading data
#   - custom data from a variable
#   - excel data
#   - csv / json / etc
#   - database(sql)

# %%
students = {
    'name': ['vaibhav', 'siya','aman','sneha ', 'aditi' , 'bhupendra'],
    'college' :['srmcem','srmcem', 'KMC','cu', 'srmcem', 'srmcem'],
    'dob' : ['13feb' , '20jan','21jun','15jan','17dec','22may']
}

sdf = pd.DataFrame(students)
sdf
# Out:
#         name college    dob
# 0    vaibhav  srmcem  13feb
# 1       siya  srmcem  20jan
# 2       aman     KMC  21jun
# 3     sneha       cu  15jan
# 4      aditi  srmcem  17dec
# 5  bhupendra  srmcem  22may

# %%
sdf.columns.tolist()
# Out:
# ['name', 'college', 'dob']

# %%
data = pd.read_excel('C:/Users/Bhuperndra Singh/Downloads/fruits.xlsx')
data
# Out:
#       Item  qty  amt
# 0   Apple   100    2
# 1   banana  400   50
# 2  orange    40   60

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Item    3 non-null      object
#  1   qty     3 non-null      int64
#  2   amt     3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 204.0+ bytes

# %%
data.columns.tolist()
# Out:
# ['Item', 'qty', 'amt']

# %%
data['Item']
# Out:
# 0     Apple
# 1     banana
# 2    orange
# Name: Item, dtype: object

# %%
data.amt
# Out:
# 0     2
# 1    50
# 2    60
# Name: amt, dtype: int64

# %%
data[['Item', 'amt']]
# Out:
#       Item  amt
# 0   Apple     2
# 1   banana   50
# 2  orange    60

# %%
data['amt']* data['qty']
# Out:
# 0      200
# 1    20000
# 2     2400
# dtype: int64

# %%
data['total'] = data['amt']*data['qty']
data
# Out:
#       Item  qty  amt  total
# 0   Apple   100    2    200
# 1   banana  400   50  20000
# 2  orange    40   60   2400

# %% [markdown]
# add coloumn

# %%
data ['crap'] = 'some crap'
data
# Out:
#       Item  qty  amt  total       crap
# 0   Apple   100    2    200  some crap
# 1   banana  400   50  20000  some crap
# 2  orange    40   60   2400  some crap

# %% [markdown]
# remove coloumn

# %%
data.drop(columns=['crap'],inplace = True)
data
# Out:
#       Item  qty  amt  total
# 0   Apple   100    2    200
# 1   banana  400   50  20000
# 2  orange    40   60   2400

# %%
data.iloc[0]
# Out:
# Item     Apple
# qty         100
# amt           2
# total       200
# Name: 0, dtype: object

# %%
data.iloc[:2]
# Out:
#      Item  qty  amt  total
# 0  Apple   100    2    200
# 1  banana  400   50  20000

# %%
data.drop(index =[1,2])
# Out:
#      Item  qty  amt  total
# 0  Apple   100    2    200

# %%
data
# Out:
#       Item  qty  amt  total
# 0   Apple   100    2    200
# 1   banana  400   50  20000
# 2  orange    40   60   2400

# %%
sdf.drop(index =[2,3])
# Out:
#         name college    dob
# 0    vaibhav  srmcem  13feb
# 1       siya  srmcem  20jan
# 4      aditi  srmcem  17dec
# 5  bhupendra  srmcem  22may

# %%
data ['qty'] = data['qty'] -10

# %%
data
# Out:
#       Item  qty  amt  total
# 0   Apple    90    2    200
# 1   banana  390   50  20000
# 2  orange    30   60   2400

# %%
data.rename(
    mapper ={'Item' : 'Product',
             'qty': 'quantity',
             'amt': 'Price',
             'total': 'Expenditure'},

    axis = 1,
    inplace = True         
)
data
# Out:
#    Product  quantity  Price  Expenditure
# 0   Apple         90      2          200
# 1   banana       390     50        20000
# 2  orange         30     60         2400

# %%
penguins = sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.drop(columns='body_mass_g')
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#         sex
# 0      Male
# 1    Female
# 2    Female
# 3       NaN
# 4    Female
# ...

# %%
penguins.drop(columns=['body_mass_g','island'])
# Out:
#     species  bill_length_mm  bill_depth_mm  flipper_length_mm     sex
# 0    Adelie            39.1           18.7              181.0    Male
# 1    Adelie            39.5           17.4              186.0  Female
# 2    Adelie            40.3           18.0              195.0  Female
# 3    Adelie             NaN            NaN                NaN     NaN
# 4    Adelie            36.7           19.3              193.0  Female
# ..      ...             ...            ...                ...     ...
# 339  Gentoo             NaN            NaN                NaN     NaN
# 340  Gentoo            46.8           14.3              215.0  Female
# 341  Gentoo            50.4           15.7              222.0    Male
# 342  Gentoo            45.2           14.8              212.0  Female
# 343  Gentoo            49.9           16.1              213.0    Male
#
# [344 rows x 5 columns]

# %%
penguins.drop(index=3)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.drop(index=[1,2,3,4,5,6])
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 7    Adelie  Torgersen            39.2           19.6              195.0
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 7         4675.0    Male
# ...

# %%
penguins.drop(index=range(10))
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 12   Adelie  Torgersen            41.1           17.6              182.0
# 13   Adelie  Torgersen            38.6           21.2              191.0
# 14   Adelie  Torgersen            34.6           21.1              198.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 10        3300.0     NaN
# 11        3700.0     NaN
# ...

# %%
np.nan
# Out:
# nan

# %% [markdown]
# find the missing number of values in each columns

# %%
penguins.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
sns.heatmap(penguins.isnull(),cbar=False)
# Out:
# <Axes: >

# %%
penguins.isnull().sum().plot(kind='bar')
# Out:
# <Axes: >

# %%
penguins.dropna()
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.shape
# Out:
# (344, 7)

# %%
penguins.dropna().shape
# Out:
# (333, 7)

# %%
penguins.dropna(inplace = True)
print(penguins.shape)
# Out:
# (333, 7)

# %%
penguins.drop_duplicates(subset =['bill_length_mm'])
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 326  Gentoo     Biscoe            41.7           14.7              210.0
# 327  Gentoo     Biscoe            53.4           15.8              219.0
# 335  Gentoo     Biscoe            55.1           16.0              230.0
# 337  Gentoo     Biscoe            48.8           16.2              222.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.sort_values(by='sex')
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 172  Chinstrap   Dream            42.4           17.3              181.0
# 136     Adelie   Dream            35.6           17.5              191.0
# 138     Adelie   Dream            37.0           16.5              185.0
# 272     Gentoo  Biscoe            45.1           14.4              210.0
# 140     Adelie   Dream            40.2           17.1              193.0
# ..         ...     ...             ...            ...                ...
# 163  Chinstrap   Dream            51.7           20.3              194.0
# 165  Chinstrap   Dream            52.0           18.1              201.0
# 167  Chinstrap   Dream            50.5           19.6              201.0
# 145     Adelie   Dream            39.0           18.7              185.0
# 343     Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 172       3600.0  Female
# 136       3175.0  Female
# ...

# %%
penguins.sort_values(by='sex', ascending = False)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 119     Adelie  Torgersen            41.1           18.6              189.0
# 179  Chinstrap      Dream            49.5           19.0              200.0
# 181  Chinstrap      Dream            52.8           20.0              205.0
# 183  Chinstrap      Dream            54.2           20.8              201.0
# ..         ...        ...             ...            ...                ...
# 206  Chinstrap      Dream            42.5           17.3              187.0
# 74      Adelie  Torgersen            35.5           17.5              190.0
# 208  Chinstrap      Dream            45.2           16.6              191.0
# 72      Adelie  Torgersen            39.6           17.2              196.0
# 172  Chinstrap      Dream            42.4           17.3              181.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# ...

# %%
penguins.sort_values(by=['sex','island'])
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 20   Adelie     Biscoe            37.8           18.3              174.0
# 22   Adelie     Biscoe            35.9           19.2              189.0
# 25   Adelie     Biscoe            35.3           18.9              187.0
# 27   Adelie     Biscoe            40.5           17.9              187.0
# 28   Adelie     Biscoe            37.9           18.6              172.0
# ..      ...        ...             ...            ...                ...
# 123  Adelie  Torgersen            41.4           18.5              202.0
# 125  Adelie  Torgersen            40.6           19.0              199.0
# 127  Adelie  Torgersen            41.5           18.3              195.0
# 129  Adelie  Torgersen            44.1           18.0              210.0
# 131  Adelie  Torgersen            43.1           19.2              197.0
#
#      body_mass_g     sex
# 20        3400.0  Female
# 22        3800.0  Female
# ...

# %% [markdown]
# - datatypes in pandas
#      - int
#      - float
#      - boolean
#      - string(not understood by pandas)
#      - datatime
#      - object(if datatypes is not understood by pandas then object is used)

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 333 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    object
#  1   island             333 non-null    object
#  2   bill_length_mm     333 non-null    float64
#  3   bill_depth_mm      333 non-null    float64
#  4   flipper_length_mm  333 non-null    float64
#  5   body_mass_g        333 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.8+ KB

# %%
penguins.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
penguins.select_dtypes(include='number')
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0              39.1           18.7              181.0       3750.0
# 1              39.5           17.4              186.0       3800.0
# 2              40.3           18.0              195.0       3250.0
# 4              36.7           19.3              193.0       3450.0
# 5              39.3           20.6              190.0       3650.0
# ..              ...            ...                ...          ...
# 338            47.2           13.7              214.0       4925.0
# 340            46.8           14.3              215.0       4850.0
# 341            50.4           15.7              222.0       5750.0
# 342            45.2           14.8              212.0       5200.0
# 343            49.9           16.1              213.0       5400.0
#
# [333 rows x 4 columns]

# %%
penguins.select_dtypes(exclude='number')
# Out:
#     species     island     sex
# 0    Adelie  Torgersen    Male
# 1    Adelie  Torgersen  Female
# 2    Adelie  Torgersen  Female
# 4    Adelie  Torgersen  Female
# 5    Adelie  Torgersen    Male
# ..      ...        ...     ...
# 338  Gentoo     Biscoe  Female
# 340  Gentoo     Biscoe  Female
# 341  Gentoo     Biscoe    Male
# 342  Gentoo     Biscoe  Female
# 343  Gentoo     Biscoe    Male
#
# [333 rows x 3 columns]

# %% [markdown]
# change the datatype of  a column

# %%
penguins['island'].astype('category')
# Out:
# 0      Torgersen
# 1      Torgersen
# 2      Torgersen
# 4      Torgersen
# 5      Torgersen
#          ...
# 338       Biscoe
# 340       Biscoe
# 341       Biscoe
# 342       Biscoe
# 343       Biscoe
# Name: island, Length: 333, dtype: category
# Categories (3, object): ['Biscoe', 'Dream', 'Torgersen']

# %%
penguins['island']=penguins['island'].astype('category')

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# - univariate , simple visualization
#  - for numerical data
#      - line plot --> .plot()
#      - bar plot --> .plot(kind='bar')
#      - box plot -> .plot(kind='box')
#      - area plot ->

# %%
penguins['bill_depth_mm'].hist()
# Out:
# <Axes: >

# %%
penguins['bill_depth_mm'].plot(figsize = (15,5))
# Out:
# <Axes: >

# %%
penguins['bill_depth_mm'].plot(kind = 'area',figsize =(15,5))
# Out:
# <Axes: >

# %%
penguins['bill_depth_mm'].plot(kind = 'box',figsize =(15,5))
# Out:
# <Axes: >

# %%
penguins['bill_depth_mm'].plot(kind = 'box',figsize =(5,3), vert = False)
# Out:
# <Axes: >

# %%
penguins['island'].value_counts()
# Out:
# island
# Biscoe       163
# Dream        123
# Torgersen     47
# Name: count, dtype: int64

# %%
penguins['island'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='island'>

# %%
penguins['bill_depth_mm'].plot(kind = 'box',figsize =(15,10))
# Out:
# <Axes: >

# %%
penguins['bill_length_mm'].hist()
# Out:
# <Axes: >

# %%
penguins[['bill_length_mm','bill_depth_mm']].plot()
# Out:
# <Axes: >

# %%
penguins[['bill_length_mm','bill_depth_mm']].plot(kind ='box', figsize =(15,5))
# Out:
# <Axes: >

# %% [markdown]
# putting columns visualization in subplots

# %%
penguins[['bill_length_mm','bill_depth_mm']].plot(layout =(1,2),subplots = True ,figsize = (15,5))
# Out:
# array([[<Axes: >, <Axes: >]], dtype=object)

# %% [markdown]
# The power of seaborn

# %%
sns.displot(data = penguins ,x = 'bill_depth_mm')

# %%
sns.displot(data = penguins ,x = 'bill_depth_mm', hue= 'island' )

# %%
sns.countplot(data = penguins , x ='island')
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %%
sns.countplot(data = penguins , x ='island' , hue = 'species')
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %% [markdown]
# bivariate analysis
#  - scatter plot
#  - violin plot
#  - pair plot

# %%
sns.scatterplot(data = penguins , x = 'bill_length_mm', y = 'bill_depth_mm')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data = penguins , x = 'bill_length_mm', y = 'bill_depth_mm', hue = 'species')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data = penguins , x = 'bill_length_mm', y = 'bill_depth_mm', hue = 'island')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.color_palette('RdBu')
# Out:
# [(0.7561707035755478, 0.21038062283737025, 0.22352941176470587),
#  (0.940715109573241, 0.6099192618223759, 0.4812764321414839),
#  (0.9856978085351787, 0.8889657823913879, 0.8320645905420992),
#  (0.8605151864667436, 0.9174163783160324, 0.9487120338331411),
#  (0.530026912725875, 0.7456362937331797, 0.8560553633217994),
#  (0.1843137254901961, 0.47266435986159167, 0.7116493656286044)]

# %%
penguins = sns.load_dataset("penguins")
sns.relplot(data=penguins, x="bill_length_mm", y="bill_depth_mm")

# %%
sns.relplot(data=penguins, x="bill_length_mm", y="bill_depth_mm", hue = 'island')

# %%
sns.relplot(
    data=penguins,
    x="bill_length_mm", y="bill_depth_mm", hue="island", style="island"
)

# %%
sns.relplot(
    data=penguins,
    x="bill_length_mm", y="bill_depth_mm", hue="island", style="sex",
)

# %%
sns.relplot(
    data=penguins, x="bill_length_mm", y="bill_depth_mm", hue="species",
)

# %%
sns.relplot(
    data=penguins,
    x="bill_length_mm", y="bill_depth_mm",
    hue="species", palette="ch:r=-.5,l=.75"
)

# %%
sns.relplot(data=penguins, x="bill_depth_mm", y="bill_length_mm", size = 'island')

# %%
sns.relplot(
    data=penguins, x="bill_depth_mm", y="bill_length_mm",
    size="island", sizes=(15, 200)
)

# %%
sns.relplot(data=penguins, x="bill_length_mm", y="bill_depth_mm", kind="line")

# %%
penguins = sns.load_dataset("penguins")
sns.relplot(data=penguins, x="bill_length_mm", y="bill_depth_mm", kind="line")

# %%
penguins = sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
dowjones = sns.load_dataset("dowjones")
sns.relplot(data=dowjones, x="Date", y="Price", kind="line")
dowjones
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\Bhuperndra Singh\miniconda3\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File c:\Users\Bhuperndra Singh\miniconda3\Lib\http\client.py:1286, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1285 """Send a complete request to the server."""
# -> 1286 self._send_request(method, url, body, headers, encode_chunked)
#
# File c:\Users\Bhuperndra Singh\miniconda3\Lib\http\client.py:1332, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1331     body = _encode(body, 'body')
# ...
